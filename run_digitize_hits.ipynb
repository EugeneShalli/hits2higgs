# %%
import acts

# %%
import sys

log = open("output_digitization.log", "w")
sys.stdout = sys.stderr = log

# %%
# !python digitize_hits.py /app/data/ttbar_H_production_p50/csv /app/acts-41.1.0/Examples/Configs/generic-digi-geometric-config.json
# Out:
# [INFO] Building tracking geometry...
# 11:42:20    GenericDetec   INFO      Building tracking geometry
# 11:42:20    GenericDetec   INFO      Building tracking geometry for Generic Detector in Gen1 mode
# 11:42:20    GenericDetec   INFO      Tracking geometry built
# [✓] Tracking geometry built.
# [INFO] Found 40000 measurement files.
# Digitizing Files:   0%|                               | 0/40000 [00:00<?, ?it/s][INFO] Converting: /app/data/ttbar_H_production_p50/csv/background/digitization/event000014219-measurements.csv
# [✓] Saved: /app/data/ttbar_H_production_p50/csv/background/digitization/event000014219-measurements_global_xyz.csv
# Digitizing Files:   0%|                     | 1/40000 [00:00<4:04:57,  2.72it/s][INFO] Converting: /app/data/ttbar_H_production_p50/csv/background/digitization/event000008707-measurements.csv
# [✓] Saved: /app/data/ttbar_H_production_p50/csv/background/digitization/event000008707-measurements_global_xyz.csv
# ...
